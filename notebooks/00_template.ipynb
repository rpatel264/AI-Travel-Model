# %% [markdown]
# # Template Notebook
#
# This notebook demonstrates how to use the Chicago processing modules interactively.

# %%
# Setup: Add parent directory to path
import sys
from pathlib import Path

# Add Chicago directory to Python path
project_root = Path().parent
chicago_dir = project_root / "Chicago"
sys.path.insert(0, str(chicago_dir))

print(f"Project root: {project_root}")
print(f"Chicago directory: {chicago_dir}")

# %%
# Import modules
# from pdf_pipeline import process_pdf, extract_text_from_pdf
# from query_chunks import query_chunks
# from retrieval_v2 import enhanced_search
# from retrieval_bullets import generate_bullets

# %%
# Example: Process a PDF
# pdf_path = project_root / "Chicago" / "Data" / "Raw" / "example.pdf"
# process_pdf(pdf_path)

# %%
# Example: Query chunks
# results = query_chunks("Chicago architecture")
# print(results)
